# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Salaries.csv")

# %%
df.head() # it gives us the 1st some rows of dataset.
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.dtypes  # it give data types of all the columns
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df.tail(10)  # it gives us the last some rows of dataframe or dataset
# Out:
#          rank discipline  phd  service     sex  salary
# 68   AsstProf          A    4        2  Female   77500
# 69       Prof          A   28        7  Female  116450
# 70   AsstProf          A    8        3  Female   78500
# 71  AssocProf          B   12        9  Female   71065
# 72       Prof          B   24       15  Female  161101
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   rank        78 non-null     object
#  1   discipline  78 non-null     object
#  2   phd         78 non-null     int64
#  3   service     78 non-null     int64
#  4   sex         78 non-null     object
#  5   salary      78 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 3.8+ KB

# %%
df["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.describe()   #count -total no. of records
                #std -
                # it gives the math function values for all columns
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df.max()
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           51
# sex             Male
# salary        186960
# dtype: object

# %%
df.min()  # it provide the minkimum value of all columns
# Out:
# rank          AssocProf
# discipline            A
# phd                   1
# service               0
# sex              Female
# salary            57800
# dtype: object

# %%
df.mean()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# phd            19.705128
# service        15.051282
# salary     108023.782051
# dtype: float64

# %%
df.phd.describe() # it provide the mathematical or math function values of particular column
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.salary.quantile(0.50) # it gives the median value for the salary column
# Out:
# 104671.0

# %%
df.phd.quantile(0.75)  # it provide the
# Out:
# 27.75

# %%
df.std()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# phd           12.498425
# service       12.139768
# salary     28293.661022
# dtype: float64

# %%
df_50=df.head(50) # using this command we can create new dataframe and in this case whatever the value we put in the () it display that.

# %%
df_50
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df_50.describe()
# Out:
#              phd    service         salary
# count  50.000000  50.000000      50.000000
# mean   21.520000  17.600000  113789.140000
# std    13.489588  13.385951   28886.605761
# min     1.000000   0.000000   57800.000000
# 25%    11.250000   6.250000   91475.000000
# 50%    20.000000  18.000000  108907.500000
# 75%    29.000000  23.000000  133884.750000
# max    56.000000  51.000000  186960.000000

# %%
df.salary
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
result1=df.salary #using this method we can add salary data in result1 , this helps in adding one column
result1
# Out:
# 0     186960
# 1      93000
# 2     110515
# 3     131205
# 4     104800
#        ...
# 73    105450
# 74    104542
# 75    124312
# 76    109954
# 77    109646
# Name: salary, Length: 78, dtype: int64

# %%
# there are are 2 data structures in pandas

type(result1) # Series is the one dimensional data one column
# Out:
# pandas.core.series.Series

# %%
result2=df[['salary','rank']] # this method will help in adding 2 or more column in another dataframe.
result2
# Out:
#     salary       rank
# 0   186960       Prof
# 1    93000       Prof
# 2   110515       Prof
# 3   131205       Prof
# 4   104800       Prof
# ..     ...        ...
# 73  105450       Prof
# 74  104542  AssocProf
# 75  124312       Prof
# 76  109954       Prof
# 77  109646       Prof
#
# [78 rows x 2 columns]

# %%
# extract particular data in new data frame
newdf=df[['salary','rank','phd']]
newdf
# Out:
#     salary       rank  phd
# 0   186960       Prof   56
# 1    93000       Prof   12
# 2   110515       Prof   23
# 3   131205       Prof   40
# 4   104800       Prof   20
# ..     ...        ...  ...
# 73  105450       Prof   18
# 74  104542  AssocProf   19
# 75  124312       Prof   17
# 76  109954       Prof   28
# 77  109646       Prof   23
#
# [78 rows x 3 columns]

# %%
df['discipline'].value_counts()  # this function will provide category and its value it means it finds the unique values
# Out:
# B    42
# A    36
# Name: discipline, dtype: int64

# %%
df['rank'].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# Male      39
# Female    39
# Name: sex, dtype: int64

# %%
#calculate basic statistics for phd coloumn
#calculate average of phd column

# %%
df.phd.describe()
# Out:
# count    78.000000
# mean     19.705128
# std      12.498425
# min       1.000000
# 25%      10.250000
# 50%      18.500000
# 75%      27.750000
# max      56.000000
# Name: phd, dtype: float64

# %%
df.phd.count()
# Out:
# 78

# %%
df.phd.mean()
# Out:
# 19.705128205128204

# %%
df.groupby(['rank']).mean()# group by rank and find the mean of
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\2483172600.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby(['rank']).mean()# group by rank and find the mean of
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['sex']).max() # groupby method will create the groups for the columns as per the category
# Out:
#         rank discipline  phd  service  salary
# sex
# Female  Prof          B   39       36  161101
# Male    Prof          B   56       51  186960

# %%
df.groupby(['sex','discipline','rank']).mean() # grouping of three columns
# Out:
#                                    phd    service         salary
# sex    discipline rank
# Female A          AssocProf  18.500000  15.500000   72128.500000
#                   AsstProf    4.833333   2.500000   72933.333333
#                   Prof       26.500000  16.125000  109631.875000
#        B          AssocProf  13.500000   8.833333   99435.666667
#                   AsstProf    6.600000   2.600000   84189.800000
#                   Prof       21.500000  17.900000  131836.200000
# Male   A          AssocProf  20.000000  17.000000   81285.000000
#                   AsstProf    3.000000   1.000000   79000.000000
#                   Prof       28.933333  22.733333  113164.400000
#        B          AssocProf  10.500000   7.500000  113404.000000
#                   AsstProf    4.666667   2.000000   88224.000000
#                   Prof       29.538462  25.846154  137989.076923

# %%
df.groupby('rank')(['discipline','phd']).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 df.groupby('rank')(['discipline','phd']).mean()
#
# TypeError: 'DataFrameGroupBy' object is not callable

# %%
grouped=df.groupby('rank')

# %%
grouped

# %%
for g in grouped:
    print(g)

# %%
df[df.salary>120000] # to display the record of grouped variables.

# %%
df.shape

# %%
df.shape[1]

# %%
df.shape[0]

# %%
df[df.salary>120000].shape[0]

# %%
tiranga=df.head(40)

# %%
tiranga

# %%
newdf=df[(df['sex']=='Male')&(df['salary']>150000)]

# %%
newdf

# %%
newdf.shape[0]

# %%
df[df['rank']!='Prof'].shape[0]
# Out:
# 32

# %%
 df # this will displays all records of dataframe
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df[4] # this command will gives the error for extracting the info by index
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.iloc[4] # the iloc[] index location for row this gives us single index
# Out:
# rank            Prof
# discipline         B
# phd               20
# service           18
# sex             Male
# salary        104800
# Name: 4, dtype: object

# %%
df.iloc[1:5,0:5] # 1 to 5 rows and 0 to 5 columns
# Out:
#    rank discipline  phd  service   sex
# 1  Prof          A   12        6  Male
# 2  Prof          A   23       20  Male
# 3  Prof          A   40       31  Male
# 4  Prof          B   20       18  Male

# %%
df.iloc[:,4] # in this we are giving the empty index for row and we have given the index for column
# Out:
# 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#        ...
# 73    Female
# 74    Female
# 75    Female
# 76    Female
# 77    Female
# Name: sex, Length: 78, dtype: object

# %%
df.iloc[:,0:3]
# Out:
#          rank discipline  phd
# 0        Prof          B   56
# 1        Prof          A   12
# 2        Prof          A   23
# 3        Prof          A   40
# 4        Prof          B   20
# ..        ...        ...  ...
# 73       Prof          B   18
# 74  AssocProf          B   19
# 75       Prof          B   17
# 76       Prof          A   28
# 77       Prof          A   23
#
# [78 rows x 3 columns]

# %%
 df.iloc[[1,3,6,8]] # this will  gives us the info for particular 1 or more random records
# Out:
#         rank discipline  phd  service   sex  salary
# 1       Prof          A   12        6  Male   93000
# 3       Prof          A   40       31  Male  131205
# 6  AssocProf          A   20       17  Male   81285
# 8       Prof          A   29       19  Male   94350

# %%
 # in this command we can simultaneously provide the index as well we can provide the names of the columns
df.loc[:,['sex','rank']] # when we provide the column names instead of index the we have to use the only loc[]
# Out:
#        sex       rank
# 0     Male       Prof
# 1     Male       Prof
# 2     Male       Prof
# 3     Male       Prof
# 4     Male       Prof
# ..     ...        ...
# 73  Female       Prof
# 74  Female  AssocProf
# 75  Female       Prof
# 76  Female       Prof
# 77  Female       Prof
#
# [78 rows x 2 columns]

# %%
df.loc[[0,1,2],['sex','rank']] # when we have the command with column names then we have to use the loc[]
# Out:
#     sex  rank
# 0  Male  Prof
# 1  Male  Prof
# 2  Male  Prof

# %%
df.iloc[::5]
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 5        Prof          A   20       20    Male  122400
# 10       Prof          B   39       33    Male  128250
# 15       Prof          B   17        3    Male  150480
# 20   AsstProf          B    4        4    Male   92000
# 25       Prof          B   35       31    Male   99418
# 30  AssocProf          B    9        7    Male  107008
# 35       Prof          B   28       23    Male  126933
# 40       Prof          A   39       36  Female  137000
# 45       Prof          B   25       25  Female  140096
# 50   AsstProf          B   10        5  Female   97032
# 55   AsstProf          A    2        0  Female   72500
# 60   AsstProf          B    3        3  Female   92000
# 65       Prof          A   36       19  Female  117555
# 70   AsstProf          A    8        3  Female   78500
# 75       Prof          B   17       17  Female  124312

# %%
df.iloc[1:30:3]#  [start:End:Function0r increment]
# Out:
#         rank discipline  phd  service   sex  salary
# 1       Prof          A   12        6  Male   93000
# 4       Prof          B   20       18  Male  104800
# 7       Prof          A   18       18  Male  126300
# 10      Prof          B   39       33  Male  128250
# 13      Prof          B   35       33  Male  162200
# 16  AsstProf          B    8        3  Male   75044
# 19      Prof          A   29       27  Male  150500
# 22  AsstProf          A    4        2  Male   73000
# 25      Prof          B   35       31  Male   99418
# 28  AsstProf          B    7        2  Male   91300

# %%
df.iloc[::-1] # all records in reverse order
# Out:
#          rank discipline  phd  service     sex  salary
# 77       Prof          A   23       15  Female  109646
# 76       Prof          A   28       14  Female  109954
# 75       Prof          B   17       17  Female  124312
# 74  AssocProf          B   19        6  Female  104542
# 73       Prof          B   18       10  Female  105450
# ..        ...        ...  ...      ...     ...     ...
# 4        Prof          B   20       18    Male  104800
# 3        Prof          A   40       31    Male  131205
# 2        Prof          A   23       20    Male  110515
# 1        Prof          A   12        6    Male   93000
# 0        Prof          B   56       49    Male  186960
#
# [78 rows x 6 columns]

# %% [markdown]
#  #Aggregation functio in pandas . Computing a statistics summary about each group
# agregation functions means:- mean ,max,min, mad( mean absolute deviation),std

# %%
df[['rank','phd']].agg(['min','max','mad','std'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\4228659566.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['rank','phd']].agg(['min','max','mad','std'])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\4228659566.py:1: FutureWarning: The 'mad' method is deprecated and will be removed in a future version. To compute the same result, you may do `(df - df.mean()).abs().mean()`.
#   df[['rank','phd']].agg(['min','max','mad','std'])
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\4228659566.py:1: FutureWarning: ['rank'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df[['rank','phd']].agg(['min','max','mad','std'])
#           rank        phd
# min  AssocProf   1.000000
# max       Prof  56.000000
# mad        NaN   9.920776
# std        NaN  12.498425

# %%
df['salary'].agg(['skew'])
# Out:
# skew    0.452103
# Name: salary, dtype: float64

# %%
df['salary'].agg(['kurt'])
# Out:
# kurt   -0.401713
# Name: salary, dtype: float64

# %%
df.var() #var() provide the variance for int data
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# phd        1.562106e+02
# service    1.473740e+02
# salary     8.005313e+08
# dtype: float64

# %%
df.values # it provide us the all data of particular dataframe it creates just array of that particular data
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.keys()
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.items()
# Out:
# <generator object DataFrame.items at 0x000002610421E020>

# %%
df.sem()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_11712\1459226325.py:1: FutureWarning: The default value of numeric_only in DataFrame.sem is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sem()
# phd           1.415168
# service       1.374558
# salary     3203.626259
# dtype: float64
