# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns
df=pd.read_csv('salaries.csv')

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.keys()
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'sex', 'salary'], dtype='object')

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
# Bar plot
df['discipline'].value_counts().plot.bar()
# Out:
# <Axes: >

# %%
# scatter plot
ages=[30,40,22,44,55]
salaries=[300000,230000,33000,55555,66000]

plt.xlabel("ages of person")
plt.ylabel("salaeries of a person")
plt.title("Salary distribution of employes")
plt.scatter(ages,salaries,color='red')

# %%
x=[-5,-2,-1,1,2,4,6,7,10]
y=[20,30,44,56,65,78,99,45,72]
plt.figure(figsize=(6,4))# size in inches
plt.suptitle('learning Visualisation',size=24)
plt.xlim(-20,20)# this is the limit of x axis
plt.ylim(10,100)#this is limit of y axis
plt.plot(x,y)

# %%
# plot graph of no.(-100,100) and its squre, use the range function
x=list(range(-100,100))
y=[i**2 for i in x]# list comprehension

plt.plot(x,y)

# %%
# this the exponansial gram
from math import exp
x=list(range(0,30))
y=[exp(i) for i in x]
plt.plot(x,y)

# %%
from math import log
x=list(range(1,101)) # we have the range start from 1 not from 0
y=[log(i) for i in x]
plt.plot(x,y)

# %%
# plot multiple graphs at a time eg-12 graphs at a time -3X4 graphs
from math import *
plt.figure(figsize=(16,9))
x=list(range(-10,11))
y=[i**2 for i in x]
plt.subplot(3,3,1)# 1 position of graph

plt.plot(x,y)

y=[i**2 for i in x]
plt.subplot(3,4,7) # 7 positions of graphs
plt.plot(x,y)

y=[sin(i) for i in x]
plt.subplot(3,4,11)# 10 positions of graph
plt.plot(x,y)
